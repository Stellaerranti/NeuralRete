# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
#from keras.callbacks import History 
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train = x_train

# %%
#(x_train, y_train),(x_test, y_test) = mnist.load_data()
#x_train = x_train /255.0

# %%
#x_test = x_test / 255.

# %%
x_train=np.expand_dims(x_train,axis=3)

# %%
x_test=np.expand_dims(x_test,axis=3)

# %%
model = tf.keras.models.Sequential([
    #with normalization
    tf.keras.layers.Conv2D(32, kernel_size = (3,3), input_shape=x_train[0].shape, activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size = (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size = (3,3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(64, kernel_size = (3,3), activation='relu', padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, kernel_size = (3,3), activation='relu', padding='same'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax), 
    
])

# %%
from keras.callbacks import History 
hist = History()
optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])
hist=model.fit(x_train, y_train, epochs=5, validation_split=0.5, class_weight={0.3,0.4,0.3})
#model.save('trained_model_for_recognizing_images .h5')
# Out:
# Using TensorFlow backend.
# Train on 30000 samples, validate on 30000 samples
# Epoch 1/5
# 30000/30000 [==============================] - 46s 2ms/sample - loss: 0.6758 - acc: 0.7847 - val_loss: 0.1520 - val_acc: 0.9550
# Epoch 2/5
# 30000/30000 [==============================] - 45s 1ms/sample - loss: 0.1675 - acc: 0.9484 - val_loss: 0.0761 - val_acc: 0.9768
# Epoch 3/5
# 30000/30000 [==============================] - 45s 2ms/sample - loss: 0.1107 - acc: 0.9668 - val_loss: 0.0585 - val_acc: 0.9817
# Epoch 4/5
# 30000/30000 [==============================] - 47s 2ms/sample - loss: 0.0822 - acc: 0.9747 - val_loss: 0.0501 - val_acc: 0.9844
# Epoch 5/5
# 30000/30000 [==============================] - 47s 2ms/sample - loss: 0.0685 - acc: 0.9794 - val_loss: 0.0392 - val_acc: 0.9885

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
model = tf.keras.models.Sequential([
    #broken 
    tf.keras.layers.Conv2D(32, kernel_size = (3,3), input_shape=x_train[0].shape, activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size = (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size = (3,3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(64, kernel_size = (3,3), activation='relu', padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, kernel_size = (3,3), activation='relu', padding='same'),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.Dense(1280, activation=tf.nn.relu),
    tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax), 
    
])

# %%
#for broken

optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])
hist_broken = model.fit(x_train, y_train, epochs=50, validation_split=0.5)
# Out:
# Train on 30000 samples, validate on 30000 samples
# Epoch 1/50
# 30000/30000 [==============================] - 83s 3ms/sample - loss: 0.1589 - acc: 0.9507 - val_loss: 0.2125 - val_acc: 0.9407
# Epoch 2/50
# 30000/30000 [==============================] - 79s 3ms/sample - loss: 0.
loss: 0.0024 - acc: 0.9994 - val_loss: 0.0482 - val_acc: 0.9914
# Epoch 50/50
# 30000/30000 [==============================] - 83s 3ms/sample - loss: 0.0021 - acc: 0.9993 - val_loss: 0.0869 - val_acc: 0.9861

# %%
loss, acc = model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 6s 575us/sample - loss: 0.0726 - acc: 0.9864

# %%
plt.plot(hist_broken.history['acc'])
plt.plot(hist_broken.history['val_acc'])
plt.title('Accuracy for broken network')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

plt.plot(hist_broken.history['loss'])
plt.plot(hist_broken.history['val_loss'])
plt.title('loss for broken network')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
#model = tf.keras.models.Sequential([
    #Whith out normalization
   # tf.keras.layers.Flatten(input_shape=(28, 28)),
   # tf.keras.layers.Dense(100, activation=tf.nn.relu),
   # tf.keras.layers.Dense(100, activation=tf.nn.relu),
    #tf.keras.layers.Dropout(0.2),
    #tf.keras.layers.Dense(10, activation=tf.nn.softmax), 
    
#])

# %%
model =  tf.keras.models.load_model('trained_model_for_recognizing_images .h5')
loss, acc = model.evaluate(x_test, y_test)
#model.save('trained_model.h1')

# %%
    model =  tf.keras.models.load_model('trained_model_for_recognizing_images .h5')
    test_im=x_train[1488]
    layer_number = 7
    layer_outputs=[layer.output for layer in model.layers[:8]]
    activation_model=tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
    activations=activation_model.predict(test_im.reshape(1,28,28,1))
    counter = 0
    
    for i in range (layer_number):
        counter = 0
        print("Layer:", format(i+1))
        first_layer_activation=activations[i]
        for j in range(4):
            fig=plt.figure(figsize=(60,60))
            for k in range(8):
                fig.add_subplot(4,32,counter+1)                
                plt.imshow(first_layer_activation[0,:,:,counter], cmap='inferno')
                counter=counter+1
            plt.show()

# %%
def display_digit(num):
    label = y_test[num]
    image = x_test[num]
    image = image.reshape(28, 28)
    plt.title('Example: {}  Label: {}'.format(num, label))
    plt.imshow(image, cmap=plt.get_cmap('gray_r'))
    plt.show()

# %%
display_digit(0)

# %%
#model =  tf.keras.models.load_model('trained_model_for_recognizing_images .h5')
def pred(pre):
    predictions = model.predict(x_test[pre:pre+1,:,:])
    print("predictions:",predictions)
    #print(y_test[pre])
    #image = x_test[pre]
    print("Estimated:",y_train[pre])
    image = x_train[pre]
    image = image.reshape(28, 28)
    plt.imshow(image, cmap=plt.get_cmap('gray_r'))
    plt.show()

# %%
#model =  tf.keras.models.load_model('trained_model_for_recognizing_images .h5')
def loss(number, loss_number):
    dir(tf.keras.losses)
    sess = tf.compat.v1.Session()
    for i in range (number):
        real =y_train[i]
        guess=model.predict(x_train[i:i+1,:,:])
        
        guess_sm=tf.nn.softmax(guess)       
        g = guess_sm.eval(session=sess)
        
        g_loss = tf.keras.losses.sparse_categorical_crossentropy(real, guess_sm)   
        l=g_loss.eval(session=sess)
        if ((i%100 == 0) and (i!=0)):
            print(i, "Have passed")
        if(l>loss_number):
            print("number:",i,"loss:",l)
            pred(i)
    sess.close()

# %%
loss(3000,2)
# Out:
# number: 80 loss: [2.3830507]
# predictions: [[8.59385764e-05 2.88591800e-05 1.25969154e-06 1.60572381e-05
#   2.6102789e-05 9.6991018e-05 6.5879873e-04 4.8023267e-06 5.0534061e-05]]
# Estimated: 4
# 1500 Have passed
# 1600 Have passed
# number: 1604 loss: [2.4587116]
# predictions: [[3.4157187e-04 9.2088798e-05 9.9831980e-01 1.0487529e-03 1.0197252e-05
#   7.8741050e-07 3.3346561e-05 6.5591143e-05 8.5529602e-05 2.3695723e-06]]
# Estimated: 4
# 1700 Have passed
# 1800 Have passed
# number: 1854 loss: [2.047957]
# predictions: [[9.5263895e-06 6.0017271e-07 9.2659839e-08 8.6095930e-08 3.0399701e-07
#   8.3213679e-05 9.9989080e-01 4.5910363e-07 1.4590611e-05 3.4943886e-07]]
# Estimated: 4
# 1900 Have passed
# 2000 Have passed
# 2100 Have passed
# 2200 Have passed
# number: 2202 loss: [2.2750633]
# predictions: [[1.3273166e-05 7.2957290e-04 3.3138786e-05 7.7698332e-06 9.9757558e-01
#   5.1259776e-05 2.2067285e-04 1.0152993e-03 3.0352015e-04 4.9950057e-05]]
# Estimated: 1
# 2300 Have passed
# 2400 Have passed
# number: 2426 loss: [2.3098638]
# predictions: [[2.2359537e-04 8.2462786e-05 1.7068967e-04 6.4095861e-04 2.2545451e-02
#   1.4539580e-03 3.6570313e-05 3.1849944e-03 4.7522242e-04 9.7118604e-01]]
# Estimated: 1
# number: 2490 loss: [2.3120942]
# predictions: [[3.7263828e-05 3.4162012e-04 1.4670705e-04 8.1340229e-05 3.2211439e-05
#   1.9092982e-05 2.3691660e-05 9.9703974e-01 1.0368249e-05 2.2678985e-03]]
# Estimated: 4
# 2500 Have passed
# number: 2554 loss: [2.2706802]
# predictions: [[2.5090688e-07 2.7350552e-07 1.0721927e-08 1.0129028e-04 9.3352980e-08
#   9.9987614e-01 2.0280053e-05 2.4050827e-08 7.3464787e-07 8.9962793e-07]]
# Estimated: 5
# 2600 Have passed
# number: 2622 loss: [2.0842562]
# predictions: [[5.1813859e-06 1.4290379e-05 1.0592656e-04 1.6699007e-05 2.2198077e-05
#   7.3517117e-07 1.4944266e-06 9.9982148e-01 5.1534294e-06 6.7610367e-06]]
# Estimated: 5
# number: 2676 loss: [2.3411794]
# predictions: [[2.3027296e-04 9.9633163e-01 1.3974829e-03 1.3223193e-05 7.4151554e-04
#   1.9102728e-05 2.3769276e-04 8.0161617e-04 2.0747853e-04 1.9948133e-05]]
# Estimated: 7
# 2700 Have passed
# number: 2720 loss: [2.4474602]
# predictions: [[7.03779340e-04 2.09270409e-04 7.11120447e-05 4.44627338e-04
#   1.18385285e-01 9.30324371e-04 2.92116572e-04 4.52021044e-03
#   1.90437417e-02 8.55399549e-01]]
# Estimated: 3
# 2800 Have passed
# 2900 Have passed
# number: 2901 loss: [2.4088404]
# predictions: [[8.0340913e-05 2.7855253e-03 1.7644021e-04 1.3920826e-04 9.8678255e-01
#   2.9684513e-04 1.0031689e-03 7.8248815e-04 6.2692766e-03 1.6841834e-03]]
# Estimated: 8

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Loss = {}, accuracy = {}".format(loss, acc))
